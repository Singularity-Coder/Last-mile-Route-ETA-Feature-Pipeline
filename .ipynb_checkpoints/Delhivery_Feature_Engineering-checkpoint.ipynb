# %% [markdown]
# # PREP FOR ANALYSIS
#
# ## Business Problem
# Delhivery wants to understand and process the data coming out of its data-engineering pipelines so the data-science team can build forecasting models.
#
# The operational goal is to:
# - Clean, sanitise and merge raw segment rows into meaningful trip-level features.
# - Compare actual delivery performance with routing-engine estimates (OSRM).
# - Identify the corridors, route types and time windows that drive cost and delay.
# - Produce actionable, non-technical recommendations that improve efficiency and profitability.
#
# ## Disclaimer
# This analysis is based on the data provided and reflects the state of the dataset at the time of analysis. Insights are derived from the dataset alone and do not necessarily represent Delhivery's broader operations. Future data may yield different results.

# %%
# %pip install --quiet pandas numpy matplotlib seaborn scipy scikit-learn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy import stats
from sklearn.preprocessing import StandardScaler

warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")
sns.set_theme(style="whitegrid")

# %% [markdown]
# # OBSERVE DATASET
#
# Load the data and inspect its structure, types, missing values and duplicates before any transformation.

# %%
# Download the Delhivery dataset from the shared drive link
# !gdown 1NcWSGa2bv0HeD0NQHOT-9P9H5n0P4tCq

df = pd.read_csv("delhivery_data.csv")
display(df.head())

print("SHAPE:------------ ")
print(df.shape)
print("\nINFO:------------ ")
df.info()

print("\n% MISSING PER COLUMN:------------ ")
print(df.isnull().sum())

print("\n% TOTAL MISSING:------------ ")
print(df.isnull().sum().sum())

print("\n% DUPLICATES:------------ ")
print(df.duplicated().sum())

# Visual missing-value map
plt.figure(figsize=(12, 5))
sns.heatmap(df.isnull(), cbar=False, yticklabels=False)
plt.title("Missing-value heatmap (raw data)")
plt.show()

# %% [markdown]
# # CLEAN & OPTIMISE DATA
#
# Steps:
# - Fix the known `destination_cente` typo.
# - Convert timestamp columns to datetime.
# - Handle missing source/destination names.
# - Drop rows with missing critical timestamps.
# - Remove columns labelled as unknown and not usable for modelling.
# - Drop exact duplicate rows.
# - Convert repetitive string columns to `category` to save memory and speed up groupby operations.

# %%
# Work on a copy so the raw dataset stays untouched
data = df.copy()

# Fix the common typo in the destination-center column
if "destination_cente" in data.columns and "destination_center" not in data.columns:
    data = data.rename(columns={"destination_cente": "destination_center"})

# Convert timestamp columns to datetime
datetime_cols = ["trip_creation_time", "od_start_time", "od_end_time", "cutoff_timestamp"]
for col in datetime_cols:
    data[col] = pd.to_datetime(data[col], errors="coerce")

# Missing location names are filled with 'Unknown' so downstream string parsing does not break
data["source_name"] = data["source_name"].fillna("Unknown")
data["destination_name"] = data["destination_name"].fillna("Unknown")

# Drop rows where critical timestamps are missing
data = data.dropna(subset=["trip_creation_time", "od_start_time", "od_end_time"])

# Drop columns explicitly described in the brief as 'Unknown'
unknown_cols = ["is_cutoff", "cutoff_factor", "cutoff_timestamp", "factor", "segment_factor"]
data = data.drop(columns=[c for c in unknown_cols if c in data.columns], errors="ignore")

# Remove exact duplicate rows
data = data.drop_duplicates().reset_index(drop=True)

# Convert repetitive string columns to category dtype
cat_cols = ["data", "route_type", "source_center", "destination_center",
            "source_name", "destination_name", "trip_uuid", "route_schedule_uuid"]
for c in cat_cols:
    if c in data.columns:
        data[c] = data[c].astype("category")

print("Cleaned shape:", data.shape)
print("\nData types after optimisation:")
print(data.dtypes)

# %% [markdown]
# # DESCRIPTIVE STATS
#
# Summarise categorical and numerical fields. The `mean - median` gap is a quick signal of skewness / outlier influence.

# %%
# Categorical summary
print("SUMMARY OF CATEGORICAL VARS:------------ ")
print(data.describe(include=["category", "object"]).T)

# Numerical summary plus median and mean-median gap
numeric_cols = data.select_dtypes(include=["number"]).columns
df_stats = data[numeric_cols].describe().T
df_stats["median"] = data[numeric_cols].median()
df_stats["mean_minus_median"] = data[numeric_cols].mean() - data[numeric_cols].median()

print("\nSUMMARY OF NUMERICAL VARS:------------ ")
print(df_stats.round(2))

print("\nUNIQUE VALUES PER COL:------------ ")
print(data.nunique())

# %% [markdown]
# # FEATURE CREATION & ROW MERGING
#
# A single trip is split into multiple segment rows. We first extract location and time features, then aggregate segments into trip-level records that can be used for modelling.
#
# Feature created:
# - `source_city`, `source_place`, `source_code`, `source_state` from `source_name`.
# - `dest_city`, `dest_place`, `dest_code`, `dest_state` from `destination_name`.
# - `corridor`: origin city → destination city.
# - `trip_year`, `trip_month`, `trip_day`, `trip_weekday`, `trip_hour`.
# - `od_duration`: hours between trip start and end.
# - `distance_band`: Short / Medium / Long haul buckets.
#
# Aggregation levels:
# 1. **Segment-level**: group by `trip_uuid + source_center + destination_center`.
# 2. **Trip-level**: group by `trip_uuid`, taking the first origin and last destination.

# %%
def extract_location_parts(name):
    """Split a name like 'Anand_VUNagar_DC (Gujarat)' into city, place, code, state."""
    if pd.isna(name) or name == "Unknown":
        return ("Unknown", "Unknown", "Unknown", "Unknown")
    state = name.split("(")[-1].strip(")") if ""("" in name else "Unknown"
    main = name.split("(")[0].strip()
    parts = main.split("_")
    city = parts[0] if len(parts) > 0 else "Unknown"
    code = parts[-1] if len(parts) > 1 else "Unknown"
    place = "_".join(parts[1:-1]) if len(parts) > 2 else "Unknown"
    return city, place, code, state

# Extract location components on the raw segment view
(data["source_city"], data["source_place"], data["source_code"], data["source_state"]) = \n    zip(*data["source_name"].apply(extract_location_parts))
(data["dest_city"], data["dest_place"], data["dest_code"], data["dest_state"]) = \n    zip(*data["destination_name"].apply(extract_location_parts))

data["corridor"] = data["source_city"].astype(str) + " → " + data["dest_city"].astype(str)

# Time features
data["trip_year"] = data["trip_creation_time"].dt.year
data["trip_month"] = data["trip_creation_time"].dt.month
data["trip_day"] = data["trip_creation_time"].dt.day
data["trip_weekday"] = data["trip_creation_time"].dt.weekday
data["trip_hour"] = data["trip_creation_time"].dt.hour
data["od_duration"] = (data["od_end_time"] - data["od_start_time"]).dt.total_seconds() / 3600.0
data["od_duration"] = data["od_duration"].clip(lower=0)

# ------------------------------------------------------------------
# Level 1: segment-level aggregation (trip + source + destination)
# ------------------------------------------------------------------
seg_agg = {
    "data": "first",
    "route_schedule_uuid": "first",
    "route_type": "first",
    "source_name": "first",
    "destination_name": "first",
    "source_center": "first",
    "destination_center": "first",
    "source_city": "first",
    "source_state": "first",
    "dest_city": "first",
    "dest_state": "first",
    "corridor": "first",
    "trip_creation_time": "first",
    "od_start_time": "min",
    "od_end_time": "max",
    "start_scan_to_end_scan": "max",
    "actual_distance_to_destination": "max",
    "actual_time": "sum",
    "osrm_time": "sum",
    "osrm_distance": "sum",
    "segment_actual_time": "sum",
    "segment_osrm_time": "sum",
    "segment_osrm_distance": "sum",
    "trip_month": "first",
    "trip_hour": "first",
    "trip_weekday": "first"
}

segment_df = data.groupby(["trip_uuid", "source_center", "destination_center"], as_index=False).agg(seg_agg)
segment_df["od_duration"] = (segment_df["od_end_time"] - segment_df["od_start_time"]).dt.total_seconds() / 3600.0
segment_df["od_duration"] = segment_df["od_duration"].clip(lower=0)

# ------------------------------------------------------------------
# Level 2: trip-level aggregation (trip_uuid only)
# ------------------------------------------------------------------
trip_agg = {
    "data": "first",
    "route_type": "first",
    "source_name": "first",
    "destination_name": "last",
    "source_center": "first",
    "destination_center": "last",
    "source_city": "first",
    "dest_city": "last",
    "source_state": "first",
    "dest_state": "last",
    "corridor": lambda x: str(x.iloc[0]).split(" → ")[0] + " → " + str(x.iloc[-1]).split(" → ")[-1],
    "trip_creation_time": "first",
    "od_start_time": "min",
    "od_end_time": "max",
    "start_scan_to_end_scan": "max",
    "actual_distance_to_destination": "sum",
    "actual_time": "sum",
    "osrm_time": "sum",
    "osrm_distance": "sum",
    "segment_actual_time": "sum",
    "segment_osrm_time": "sum",
    "segment_osrm_distance": "sum",
    "trip_month": "first",
    "trip_hour": "first",
    "trip_weekday": "first"
}

trip_df = segment_df.groupby("trip_uuid", as_index=False).agg(trip_agg)
trip_df["od_duration"] = (trip_df["od_end_time"] - trip_df["od_start_time"]).dt.total_seconds() / 3600.0
trip_df["od_duration"] = trip_df["od_duration"].clip(lower=0)

# Derived comparison features
trip_df["actual_minus_osrm_time"] = trip_df["actual_time"] - trip_df["osrm_time"]
trip_df["actual_minus_osrm_distance"] = trip_df["actual_distance_to_destination"] - trip_df["osrm_distance"]
trip_df["distance_band"] = pd.cut(
    trip_df["actual_distance_to_destination"],
    bins=[0, 50, 200, np.inf],
    labels=["Short (<50km)", "Medium (50-200km)", "Long (>200km)"]
)

print("Segment-level shape:", segment_df.shape)
print("Trip-level shape:", trip_df.shape)
trip_df.head()

# %% [markdown]
# # OUTLIER DETECTION (IQR)
#
# Logistics data contains extreme distances or times (data-entry errors, very long routes, etc.). We detect outliers using the IQR method and cap them so they do not distort models or summaries.
#
# We also check where the high-value outliers sit — in Delhivery's case, unusually long distances may indicate FTL routes that should not be treated as noise.

# %%
numeric_cols = [
    "actual_time", "osrm_time", "actual_distance_to_destination",
    "osrm_distance", "segment_actual_time", "segment_osrm_time",
    "segment_osrm_distance", "start_scan_to_end_scan", "od_duration"
]

def iqr_outlier_info(s: pd.Series):
    q1, q3 = s.quantile(0.25), s.quantile(0.75)
    iqr = q3 - q1
    lower, upper = q1 - 1.5 * iqr, q3 + 1.5 * iqr
    mask = (s < lower) | (s > upper)
    return lower, upper, mask

outlier_rows = []
for col in numeric_cols:
    if col not in trip_df.columns:
        continue
    lower, upper, mask = iqr_outlier_info(trip_df[col])
    outlier_rows.append([col, lower, upper, int(mask.sum())])
    if col == "actual_distance_to_destination":
        print("\nHigh-distance outliers by route_type:")
        print(trip_df.loc[mask, "route_type"].value_counts())

outlier_df = pd.DataFrame(outlier_rows, columns=["Variable", "IQR_Lower", "IQR_Upper", "Outliers_Count"])
print("\nIQR outlier summary (trip-level):\n", outlier_df)

# Cap outliers in-place on the trip-level dataset
for col in numeric_cols:
    if col not in trip_df.columns:
        continue
    lower, upper, _ = iqr_outlier_info(trip_df[col])
    trip_df[col] = trip_df[col].clip(lower, upper)

# Visual check after capping
plot_cols = ["actual_time", "actual_distance_to_destination", "osrm_time"]
trip_df[plot_cols].plot(kind="box", subplots=True, layout=(1, 3), figsize=(15, 4))
plt.suptitle("Key numeric fields after IQR capping")
plt.tight_layout()
plt.show()

# %% [markdown]
# # COMPARISON & HYPOTHESIS TESTS
#
# The brief asks us to compare aggregated time and distance fields. We use scatter plots + Pearson correlation and paired t-tests to quantify the relationship between actual and estimated values.

# %%
def compare_fields(df, x, y, title):
    r = df[[x, y]].corr().iloc[0, 1]
    plt.figure(figsize=(7, 5))
    sns.scatterplot(data=df, x=x, y=y, hue="route_type", alpha=0.5)
    plt.plot(df[x], df[x], color="red", linestyle="--", label="y=x")
    plt.title(f"{title} (r={r:.2f})")
    plt.legend()
    plt.show()
    return r

pairs = [
    ("actual_time", "osrm_time"),
    ("actual_distance_to_destination", "osrm_distance"),
    ("actual_time", "segment_actual_time"),
    ("osrm_distance", "segment_osrm_distance"),
    ("osrm_time", "segment_osrm_time"),
    ("od_duration", "start_scan_to_end_scan")
]

results = []
for x, y in pairs:
    r = compare_fields(trip_df, x, y, f"{x} vs {y}")
    t, p = stats.ttest_rel(trip_df[x].dropna(), trip_df[y].dropna())
    results.append({"Pair": f"{x} vs {y}", "Correlation": r, "t_stat": t, "p_value": p})
    print(f"{x} vs {y}: corr={r:.3f}, paired t={t:.2f}, p={p:.3e}\n")

pd.DataFrame(results).round(4)

# %% [markdown]
# # MODELLING PREP: CATEGORICAL ENCODING & SCALING
#
# We create a modelling-ready copy of the trip-level data:
# - One-hot encode `route_type` (FTL vs Carting).
# - Standardise numeric features so time and distance are on comparable scales for downstream models.
#
# High-cardinality identifiers (trip_uuid, centers, corridors, states) are kept as metadata but not dummied.

# %%
# Keep an unscaled EDA copy and create a modelling copy
eda_df = trip_df.copy()
model_df = trip_df.copy()

# One-hot encode route_type
model_df = pd.get_dummies(model_df, columns=["route_type"], prefix="route", drop_first=False)

# Standardise numeric modelling features
scale_cols = [c for c in numeric_cols if c in model_df.columns]
scaler = StandardScaler()
model_df[scale_cols] = scaler.fit_transform(model_df[scale_cols])

print("Modelling-ready shape:", model_df.shape)
print("Route-type dummy columns:", [c for c in model_df.columns if c.startswith("route_")])
model_df[scale_cols + [c for c in model_df.columns if c.startswith("route_")]].head()

# %% [markdown]
# # MONEY LENS (OPERATING COST / EFFICIENCY PROXY)
#
# Delhivery does not provide price per shipment in this dataset, so we use distance and time as the main cost drivers: fuel, vehicle wear, driver hours and asset utilisation all scale with these two variables.
#
# This section answers: where is the operating effort concentrated, and is volume aligned with cost?

# %%
# Route-type mix vs distance/time mix (trip-level)
mix = pd.DataFrame({
    "Trips": eda_df["route_type"].value_counts(),
    "TripShare": eda_df["route_type"].value_counts(normalize=True).round(4),
    "TotalDistance_km": eda_df.groupby("route_type")["actual_distance_to_destination"].sum().round(2),
    "DistanceShare": (eda_df.groupby("route_type")["actual_distance_to_destination"].sum() /
                    eda_df["actual_distance_to_destination"].sum()).round(4),
    "TotalTime_h": eda_df.groupby("route_type")["actual_time"].sum().round(2),
    "TimeShare": (eda_df.groupby("route_type")["actual_time"].sum() /
                eda_df["actual_time"].sum()).round(4)
})

print("Route-type mix vs resource consumption:\n", mix)

# Visual: trip share vs distance share vs time share
mix[["TripShare", "DistanceShare", "TimeShare"]].plot(kind="bar", figsize=(8, 5))
plt.title("Trip share vs distance share vs time share by route type")
plt.ylabel("Share")
plt.xticks(rotation=0)
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# # PROBABILITIES (CONTINGENCY TABLE)
#
# We build two-way contingency tables to answer routing rule-of-thumb questions such as 'What is the probability a long-haul trip is FTL?'

# %%
def contingency_probs(row_var: str, col_var: str, df):
    ct = pd.crosstab(df[row_var], df[col_var])
    joint = ct / ct.values.sum()
    row_marg = joint.sum(axis=1)
    col_marg = joint.sum(axis=0)
    p_row_given_col = joint.div(col_marg, axis=1)   # P(row | col)
    p_col_given_row = joint.div(row_marg, axis=0)   # P(col | row)
    return ct, joint, row_marg, col_marg, p_row_given_col, p_col_given_row

# We need route_type as a plain string for crosstabs
eda_df["route_type_str"] = eda_df["route_type"].astype(str)
eda_df["distance_band_str"] = eda_df["distance_band"].astype(str)

# Time-of-day band: business hours vs after hours
eda_df["hour_band"] = pd.cut(
    eda_df["trip_hour"],
    bins=[0, 8, 18, 24],
    labels=["Night (0-8)", "Business (8-18)", "Evening (18-24)"],
    include_lowest=True
)

prob_vars = ["distance_band_str", "hour_band"]
p_map = {}
for col in prob_vars:
    ct, joint, row_marg, col_marg, p_row_given_col, p_col_given_row = \n        contingency_probs("route_type_str", col, eda_df)
    p_map[col] = p_row_given_col
    print(f"\nContingency: route_type x {col} (counts)-------------------\n", ct)
    print(f"\nP(route_type | {col})\n", p_row_given_col.round(4))
    print(f"\nP({col} | route_type)\n", p_col_given_row.round(4))

# %% [markdown]
# # CHART SET
#
# Guided visual analysis answering the 6 core EDA questions. Every chart maps directly to a business decision.

# %%
# Key categorical plots
cat_plot_cols = ["route_type", "distance_band", "trip_weekday"]
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
for ax, col in zip(axes, cat_plot_cols):
    sns.countplot(data=eda_df, x=col, ax=ax, palette="Set2")
    ax.set_title(f"{col} (count of trips)")
    ax.tick_params(axis="x", rotation=45)
plt.tight_layout()
plt.show()

# Top 10 source states
plt.figure(figsize=(8, 4))
eda_df["source_state"].value_counts().head(10).plot(kind="barh", color="teal")
plt.title("Top 10 source states by trip volume")
plt.xlabel("Number of trips")
plt.show()

# Numeric distributions
num_plot_cols = ["actual_time", "actual_distance_to_destination", "osrm_time"]
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
for ax, col in zip(axes, num_plot_cols):
    sns.histplot(data=eda_df, x=col, bins=30, kde=True, ax=ax)
    ax.set_title(f"{col} distribution")
plt.tight_layout()
plt.show()

# Strong separators: boxplots by route type
box_cols = ["actual_time", "actual_distance_to_destination", "start_scan_to_end_scan"]
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
for ax, col in zip(axes, box_cols):
    sns.boxplot(data=eda_df, x="route_type", y=col, ax=ax, palette="Set2")
    ax.set_title(f"{col} by route_type")
plt.tight_layout()
plt.show()

# Correlation heatmap (trip-level numeric features)
corr_cols = [c for c in numeric_cols if c in eda_df.columns]
plt.figure(figsize=(9, 7))
sns.heatmap(eda_df[corr_cols].corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation heatmap (trip-level numeric features)")
plt.show()

# Actual vs OSRM time, coloured by route type
plt.figure(figsize=(7, 5))
sns.scatterplot(data=eda_df, x="osrm_time", y="actual_time", hue="route_type", alpha=0.5)
plt.plot(eda_df["osrm_time"], eda_df["osrm_time"], color="red", linestyle="--")
plt.title("Actual time vs OSRM time by route type")
plt.show()

# %% [markdown]
# # ROUTE/CORRIDOR PROFILE TABLE (TRIP-WISE)
#
# A product-wise customer profile in Slimfit maps to a route-type-wise trip profile here. This table summarises the typical distance, time and delay characteristics of each route mode.

# %%
route_profile = eda_df.groupby("route_type", observed=False).agg(
    Trips=("route_type", "size"),
    Median_Distance_km=("actual_distance_to_destination", "median"),
    Median_Actual_Time_h=("actual_time", "median"),
    Median_OSRM_Time_h=("osrm_time", "median"),
    Median_Scan_Time_h=("start_scan_to_end_scan", "median"),
    Median_OD_Duration_h=("od_duration", "median"),
    Avg_Actual_vs_OSRM=("actual_minus_osrm_time", "mean")
)
print("\nRoute-type profile (medians):\n", route_profile.round(2))

# Top 5 corridors by volume and their typical delay
corridor_profile = eda_df.groupby("corridor", observed=False).agg(
    Trips=("corridor", "size"),
    Median_Distance_km=("actual_distance_to_destination", "median"),
    Median_Actual_Time_h=("actual_time", "median"),
    Avg_Time_Bias_h=("actual_minus_osrm_time", "mean")
).sort_values("Trips", ascending=False).head(5)
print("\nTop 5 corridors by volume:\n", corridor_profile.round(2))

# %% [markdown]
# # MONEY-FOCUSED SEGMENT KPIs
#
# We segment the trips by distance band, source state and hour-of-day to see where the operational load (distance + time) is concentrated.

# %%
# Distance-band KPIs
seg_distance = eda_df.groupby("distance_band", observed=False).agg(
    Trips=("distance_band", "size"),
    Total_Distance_km=("actual_distance_to_destination", "sum"),
    Total_Time_h=("actual_time", "sum"),
    Avg_Distance_km=("actual_distance_to_destination", "mean"),
    Avg_Time_h=("actual_time", "mean")
)
print("KPIs by distance band:\n", seg_distance.round(2))

# Top source states by operational load
seg_state = eda_df.groupby("source_state", observed=False).agg(
    Trips=("source_state", "size"),
    Total_Distance_km=("actual_distance_to_destination", "sum"),
    Avg_Time_h=("actual_time", "mean")
).sort_values("Trips", ascending=False).head(5)
print("\nTop source states by volume:\n", seg_state.round(2))

# Hour-of-day KPIs
seg_hour = eda_df.groupby("hour_band", observed=False).agg(
    Trips=("hour_band", "size"),
    Avg_Actual_Time_h=("actual_time", "mean"),
    Avg_OSRM_Time_h=("osrm_time", "mean")
)
print("\nKPIs by hour band:\n", seg_hour.round(2))

# %% [markdown]
# # KEY BUSINESS ANSWERS
#
# Clear probability answers that can be used directly by operations and planning teams.

# %%
print("\nKey probabilities:")
print("P(FTL | Long distance)   =", round(float(p_map["distance_band_str"].loc["FTL", "Long (>200km)"]), 4))
print("P(Carting | Short distance) =", round(float(p_map["distance_band_str"].loc["Carting", "Short (<50km)"]), 4))
print("P(FTL | Business hours)  =", round(float(p_map["hour_band"].loc["FTL", "Business (8-18)"]), 4))
print("P(Carting | Night hours) =", round(float(p_map["hour_band"].loc["Carting", "Night (0-8)"]), 4))

# Overall OSRM bias
bias_ratio = eda_df["actual_time"].sum() / eda_df["osrm_time"].sum()
print(f"\nOverall actual time / OSRM time ratio = {bias_ratio:.2f}")
print("Interpretation: actual operations take {:.0%} of the OSRM estimate on average.".format(bias_ratio))

# %% [markdown]
# # CONCLUSION
#
# ## Executive Summary
# Carting likely dominates short-haul, high-frequency moves, while FTL carries the longer, heavier routes. The actual time taken by trips is systematically higher than the OSRM routing estimate, which means the current ETA engine under-predicts real-world delivery time. The top corridors and source states concentrate a disproportionate share of volume and distance, so fixing them first delivers the biggest operational return.
#
# ## Volume vs operating effort
# - Share of trips and share of distance/time are not identical across route types.
# - A route type with fewer trips but high distance share consumes a large amount of fleet capacity and fuel.
# - Reducing per-km inefficiency on the high-distance route type has a bigger cost impact than shaving time off short carting routes.
#
# ## Route-type profiles
# - **Carting**: shorter distances, smaller time variance, the workhorse for hub-and-spoke distribution.
# - **FTL**: longer distances, higher absolute times, the mode that drives network mileage and fuel cost.
#
# ## What the probabilities say
# - Long-distance trips are heavily FTL; short-distance trips are heavily Carting. This is the core routing rule.
# - Business-hour creation dominates both modes, but night/evening patterns can be used to plan staffing and fleet parking.
#
# ## Outliers
# - High-distance outliers sit mostly in FTL. These are not necessarily data errors; they are the long-haul lanes that need dedicated capacity planning rather than blanket outlier removal.
#
# ## Recommendations
# 1. **Recalibrate the ETA model** using the observed actual/OSRM bias ratio. If actual times are consistently X% above OSRM, add that buffer to customer-facing ETAs to reduce late deliveries and customer-service cost.
# 2. **Segment ETA logic by route type and distance band** because FTL and Carting have different time/distance signatures. A single global estimate will always miss on one mode.
# 3. **Prioritise the top 5 corridors and top source states** for route optimisation and hub capacity. They carry the most volume, so even a small per-trip improvement compounds into large savings.
# 4. **Use the routing rule-of-thumb** from the probability tables: long-haul planning defaults to FTL, short-haul defaults to Carting. Use this to automate pre-routing decisions and reduce manual planning overhead.
# 5. **Schedule fleet and staff around creation-hour peaks** so that inbound trips are not waiting at hubs because of shift gaps.
#
# ## Limitations
# - The dataset does not include actual cost, price or margin per trip, so the 'money lens' is a proxy based on distance and time.
# - The data only covers trips that entered the Delhivery system; it does not reveal lost demand or external disruptions.
# - Causality cannot be claimed: correlations between route type and distance reflect operating design, not a causal effect of changing the mode.
